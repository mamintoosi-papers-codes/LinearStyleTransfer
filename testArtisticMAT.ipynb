# %%
# !gdown https://drive.google.com/uc?id=1H9T5rfXGlGCUh04DGkpkMFbVnmscJAbs
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1H9T5rfXGlGCUh04DGkpkMFbVnmscJAbs
# To: /content/models.zip
# 111MB [00:04, 25.1MB/s]

# %%
# %cd ..
# !unzip models.zip
# !rm models.zip
# Out:
# Archive:  models.zip
#    creating: models/
#   inflating: models/vgg_r51.pth
#   inflating: models/vgg_r41.pth
#   inflating: models/vgg_r31.pth
#   inflating: models/r41.pth
#   inflating: models/r31.pth
#   inflating: models/dec_r41.pth
#   inflating: models/dec_r31.pth
#   inflating: models/r41_spn.pth

# %%
# %cd ..
# %rm -r  LinearStyleTransfer

# %%
# !git clone https://github.com/mamintoosi-papers-codes/LinearStyleTransfer.git
# Out:
# Cloning into 'LinearStyleTransfer'...
# remote: Enumerating objects: 972, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 972 (delta 1), reused 7 (delta 1), pack-reused 964
# Receiving objects: 100% (972/972), 273.12 MiB | 36.49 MiB/s, done.
# Resolving deltas: 100% (207/207), done.

# %%
# %cd LinearStyleTransfer
# Out:
# /content/LinearStyleTransfer

# %%
# !ls /content

# %%
# %run TestArtistic.py --vgg_dir /content/models/vgg_r41.pth --decoder_dir /content/models/dec_r41.pth --matrixPath /content/models/r41.pth --layer r41
# Out:
# ----------------- Options ---------------
#                 batchSize: 1
#               contentPath: data/content/
#                      cuda: True
#               decoder_dir: /content/models/dec_r41.pth
#                  fineSize: 256
#                     layer: r41
#                  loadSize: 256
#                matrixPath: /content/models/r41.pth
#                      outf: Artistic/
#                 stylePath: data/style/
#                   vgg_dir: /content/models/vgg_r41.pth
# ----------------- End -------------------
# Transferred image saved at Artistic/img (42)_b1d10d08-743fd86c.png
# Transferred image saved at Artistic/img (42)_b1d4b62c-89eeb5d3.png
# Transferred image saved at Artistic/img (42)_b1e62c91-eca210a9.png
# Transferred image saved at Artistic/img (42)_b1f20aa0-50213047.png
# Transferred image saved at Artistic/img (44)_b1d10d08-743fd86c.png
# Transferred image saved at Artistic/img (44)_b1d4b62c-89eeb5d3.png
# ...

# %%
# !zip -r artistic.zip Artistic/
# Out:
#   adding: Artistic/ (stored 0%)
#   adding: Artistic/img (79)_b1e62c91-eca210a9.png (deflated 0%)
#   adding: Artistic/opt.txt (deflated 72%)
#   adding: Artistic/img (51)_b1e62c91-eca210a9.png (deflated 0%)
#   adding: Artistic/img (79)_b1f20aa0-50213047.png (deflated 0%)
#   adding: Artistic/img (44)_b1f20aa0-50213047.png (deflated 0%)
#   adding: Artistic/img (51)_b1d4b62c-89eeb5d3.png (deflated 0%)
#   adding: Artistic/img (44)_b1e62c91-eca210a9.png (deflated 0%)
#   adding: Artistic/img (42)_b1d10d08-743fd86c.png (deflated 0%)
#   adding: Artistic/img (51)_b1d10d08-743fd86c.png (deflated 0%)
#   adding: Artistic/img (79)_b1d10d08-743fd86c.png (deflated 0%)
#   adding: Artistic/img (51)_b1f20aa0-50213047.png (deflated 0%)
#   adding: Artistic/img (44)_b1d10d08-743fd86c.png (deflated 0%)
#   adding: Artistic/img (44)_b1d4b62c-89eeb5d3.png (deflated 0%)
#   adding: Artistic/img (42)_b1e62c91-eca210a9.png (deflated 0%)
# ...

# %%
# !rm -r data/content/*
# !rm -r data/style/*
# !rm Artistic/*
# Out:
# rm: cannot remove 'data/content/*': No such file or directory
# rm: cannot remove 'data/style/*': No such file or directory

# %%
# Local 
# %run TestArtistic.py --vgg_dir models/vgg_r41.pth --decoder_dir C:/Archive/data/models/LinearStyleTransfer/models/dec_r41.pth --matrixPath C:/Archive/data/models/LinearStyleTransfer/models/r41.pth --layer r41
